# %% [markdown]
# # Building RAG Baseline

# %%
# !pip install -q faiss-cpu rank-bm25 groq

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import faiss
from rank_bm25 import BM25Okapi
import re
from groq import Groq

# %%
data_path = "/kaggle/input/rag-project/news_subset.csv"

df = pd.read_csv(data_path)
print(df.head())
# Out:
#        id                                              title  \
# 0   74444  وزیر دفاع دولت پیشبرد امور لبنان، سرپرستی وزار...
# 1  181228              ۶۶۰ یتیم در استان سمنان حمایت می‌شوند
# 2  162347  وال‌استریت‌ژورنال: ایران تولید تجهیزات سانتریف...
# 3   44572  ۱۸ بقعه استان مرکزی میزبان طرح نوروزی و آرامش ...
# 4   14794  شیره‌کش‌خانه‌های لاکچری در رژیم پهلوی!/ کار و ...
#
#                   short_link      service       subgroup  \
# 0        http://fna.ir/1d3ps    بین الملل       غرب آسیا
# 1  http://mehrnews.com/xZdsH      استانها          سمنان
# 2        http://fna.ir/4wug9    بین الملل  آمریکا، اروپا
# 3       http://fna.ir/f354b5      استانها          مرکزی
# 4       http://fna.ir/f2fm8j  آرشیو اخبار  دیگر رسانه ها
#
#                                             abstract  \
# 0  پس از استعفای وزیر امور خارجه دولت پیشبرد امور...
# 1  سمنان- مدیرکل کمیته امداد استان سمنان گفت: ماه...
# 2  وال‌استریت‌ژورنال: ایران تولید تجهیزات سانتریف...
# 3  مدیرکل اوقاف و امور خیریه استان مرکزی گفت: ۱۸ ...
# 4  گزارش ۷۱ سال قبل روزنامه خراسان از هزار شیره‌ک...
#
#                                                 body  \
# 0  به گزارش گروه بین الملل خبرگزاری فارس، پایگاه ...
# 1  به گزارش خبرنگار مهر، محمدحسین ذوالفقاری صبح س...
# 2  به گزارش گروه بین الملل خبرگزاری فارس، دیپلمات...
# 3  حجت لاسلام عبدالله واحدی در گفت وگو با خبرنگار...
# 4  به گزارش گروه دیگر رسانه های خبرگزاری فارس، مس...
#
#                                                 tags      published_datetime  \
# 0  میشل عون, زینه عکر, وزیر دفاع دولت پیشبرد امور...     2021-05-19 10:53:13
# 1  کمیته امداد استان سمنان, طرح محسنین, محمدحسین ...  01/03/2023 10:45:00 AM
# 2                               برنامه هسته‌ای ایران     2021-11-16 07:56:51
# 3    فارس اراك, استان مرکزی, طرح نوروزی, اراک, آرامش     2021-03-17 12:13:40
# 4                       تریاک, مواد مخدر, رژیم پهلوی     2021-01-27 02:45:30
#
#   agency_name
# 0    FarsNews
# 1    MehrNews
# 2    FarsNews
# 3    FarsNews
# 4    FarsNews

# %% [markdown]
# ## Chunking the dataset documents

# %%
def chunking(df):
    chunks = []
    for i in range(len(df)):
        text = df['title'].iloc[i] + '\n' + df['body'].iloc[i]
        
        if len(text)<=800:
            row = [0, i, text, df['subgroup'].iloc[i], df['published_datetime'].iloc[i]]
            chunks.append(row)
        else:
            # Calculating the number of chunks
            n_chunks = int(np.ceil((len(text) - 800) / 650)) + 1
            for c in range(n_chunks):
                row = [c, i, text[c*650:c*650+800], df['subgroup'].iloc[i], df['published_datetime'].iloc[i]]
                chunks.append(row)
    return pd.DataFrame(data=chunks, columns=['chunk_id', 'doc_id', 'text', 'category', 'date'])

chunks_df = chunking(df)
print(chunks_df)
# Out:
#        chunk_id  doc_id                                               text  \
# 0             0       0  وزیر دفاع دولت پیشبرد امور لبنان، سرپرستی وزار...
# 1             1       0  زمان داعش آوردند و [بذر] آن ها را برای ما در د...
# 2             0       1  ۶۶۰ یتیم در استان سمنان حمایت می‌شوند\nبه گزار...
# 3             1       1   شود. ذوالفقاری با بیان اینکه در این طرح، افرا...
# 4             0       2  وال‌استریت‌ژورنال: ایران تولید تجهیزات سانتریف...
# ...         ...     ...                                                ...
# 69857         2   19998  ارش ۱۰۰ میلیمتری در بالادست سدهای استان در ۲ ه...
# 69858         3   19998  متر مکعب بر ثانیه رسیده است تا بتوانیم حجم سد ...
# 69859         4   19998  تاهای واقع در مسیر رودخانه تخلیه شده است تا سی...
# 69860         0   19999  ۱۰۷ مادر و همسر شهید  در خورموج تجلیل شدند\nبه...
# 69861         1   19999   ام البنین (سلام الله علیها) هدیه گرفته اند. و...
#
#             category                    date
# 0           غرب آسیا     2021-05-19 10:53:13
# 1           غرب آسیا     2021-05-19 10:53:13
# 2              سمنان  01/03/2023 10:45:00 AM
# 3              سمنان  01/03/2023 10:45:00 AM
# 4      آمریکا، اروپا     2021-11-16 07:56:51
# ...              ...                     ...
# 69857    نفت و انرژی     2022-01-17 01:54:15
# 69858    نفت و انرژی     2022-01-17 01:54:15
# 69859    نفت و انرژی     2022-01-17 01:54:15
# 69860          بوشهر  01/06/2023 23:18:00 PM
# 69861          بوشهر  01/06/2023 23:18:00 PM
#
# [69862 rows x 5 columns]

# %% [markdown]
# ## Lexical Embedding by BM-25

# %%
def tokenize(text):
    return re.findall(r"\w+", text.lower())

tokenized_docs = [tokenize(c) for c in chunks_df['text']]
bm25 = BM25Okapi(tokenized_docs)

# %% [markdown]
# ## Semantic Embedding by paraphrase-multilingual-MiniLM-L12-v2

# %%
model = SentenceTransformer("sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2")
embeddings = model.encode(chunks_df['text'], normalize_embeddings=True)

# Making FAISS Index
dim = embeddings.shape[1]
index = faiss.IndexFlatIP(dim)
index.add(embeddings)
# Out:
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ## Retrieval Function

# %%
def retrieve(question, embd_model, top_k=5):
    if embd_model == 'lexical':
        bm25_scores = bm25.get_scores(tokenize(question))
        top_indices = np.argsort(bm25_scores)[::-1][:top_k]
        bm25_docs = [chunks_df['text'][i] for i in top_indices]
        doc_ids = [chunks_df['doc_id'][i] for i in top_indices]
        return bm25_docs, doc_ids

    if embd_model == 'semantic':
        q_embd = model.encode(question, normalize_embeddings=True)
        scores, idx = index.search(q_embd.reshape(1, -1), k=top_k)
        semantic_docs = [chunks_df['text'][i] for i in idx[0]]
        doc_ids = [chunks_df['doc_id'][i] for i in idx[0]]
        return semantic_docs, doc_ids

    # First retrieve 20 chunks by BM-25 then rerank using semantic model
    if embd_model == 'hybrid':
        bm25_scores = bm25.get_scores(tokenize(question))
        top_indices = np.argsort(bm25_scores)[::-1][:20]

        q_embd = model.encode(question, normalize_embeddings=True)
        scores = np.array([embeddings[i]@q_embd.T  for i in top_indices])
        idx = np.argsort(scores)[::-1][:top_k]
        reranked_idx = [top_indices[i] for i in idx]
        hybrid_docs = [chunks_df['text'][i] for i in reranked_idx]
        doc_ids = [chunks_df['doc_id'][i] for i in reranked_idx]
        return hybrid_docs, doc_ids

# %% [markdown]
# ## Generate answer with LLM

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
API_KEY = user_secrets.get_secret("groq")

client = Groq(api_key=API_KEY)

sys_prompt = """You are a helpful assistant. Your role is to answer user's questions, based on
the potentially relevant pieces of Persian news given to you as context.
If the given context is not relevant, say that you don't have enough information to answer.
Always answer in Persian. Try to answer as concisely as possible, without missing important details.
"""

def answer(query, embd_model):
    context_docs, ids = retrieve(query, embd_model)
    sep = '\n' + '-'*50 + '\n'
    context = sep.join(context_docs)
    
    prompt = f"""This is the context:
    {context}
    **********************
    Based on the context answer the user's question.
    Question: {query}
    """
    chat_completion = client.chat.completions.create(
        messages=[
            {"role": "system", "content": sys_prompt},
            {"role": "user", "content": prompt}
        ],
        model="llama-3.1-8b-instant",
        temperature=1,
        max_completion_tokens=1024
    )
    response = chat_completion.choices[0].message.content
    return response, ids, context_docs

# %%
query = "سرمربی تیم بارسلونا کیه؟"
result, doc_ids, _ = answer(query, 'hybrid')
print("Based on documents:", doc_ids)
print(result)
# Out:
# Based on documents: [np.int64(9716), np.int64(14036), np.int64(756), np.int64(10275), np.int64(16561)]
# رونالد کومان سرمربی هدایت تیم بارسلونا را برعهده دارد.

# %%
df['body'][9716]
# Out:
# 'به گزارش خبرگزاری فارس، امروز انتخابات بارسلونا برای ریاست بعدی باشگاه برگزار خواهد شد و ۱۱۰۲۹۰ عضو در این انتخابات شرکت خواهند کرد. از این تعداد ۲۰۶۶۳ عضو به صورت الکترونیکی رای خواهند داد که این سیستم برای اولین بار به خاطر ویروس کرونا اجرا خواهد شد. ریاست بعدی باشگاه از بین خوان لاپورتا، ویکتور فونت و تونی فریشا انتخاب خواهد شد و باید دید اعضای هواداری باشگاه بارسلونا چه کسی برای ادامه راه انتخاب خواهند کرد. در گزارش زیر به بررسی برنامه های کاندیداها خواهیم پرداخت اما ابتدا مروری بر عملکرد روسای باشگاه بارسلونا از سال ۲۰۰۳ تا ۲۰۲۰ داشته باشیم. *لاپورتا – راسل – بارتومیو (آغاز شکوه بارسلونا تا رسوایی بزرگ) از سال ۲۰۰۳ خوان لاپورتا مدیریت باشگاه را برعهده گرفت و توانست با آوردن فرانک رایکارد، رونالدینیو و اهتمام به مدرسه فوتبال بارسلونا، این تیم را احیا کند و به قله فوتبال برساند. در سال ۲۰۰۸ لاپورتا، سرمربی وقت بارسلونای ب یعنی پپ گواردیولا را جانشین رایکارد کرد تا سلطه «تیکی تاکا» ، گواردیولا و لیونل مسی آغاز شود و دوره جدیدی بارسلونا در تاریخ بسازد. لاپورتا با ۱۲ جام در سال ۲۰۱۰ جای خود را به ساندرو راسل داد و این مدیر ۴ سال بر مسند مدیریت باشگاه بارسلونا نشست. در ژانویه ۲۰۱۴ ، راسل به دلیل اتهام پول شویی با استفاده از حق پخش شبکه تلویزیونی در برزیل دادگاهی شد و جای خود را به دستیار خود، بارتومیو داد. بارتومیو نیز از سال ۲۰۱۴ تا ۲۰۲۰ مدیریت باشگاه را برعهده گرفت ولی او نیز سرانجام به دلیل اتفاقات فصل گذشته و نتیجه ضعیف باشگاه و اختلاف با مسی مجبور به استعفا شد و کارلس تاسکتس مدیریت موقت را برعهده گرفت. هفته گذشته نیز بارتومیو به دلیل موضوع بارساگیت دستگیر شد تا به سومین مدیر تاریخ بارسلونا بدل شود که زندان را تجربه می کند. (گزارش کامل را در اینجا بخوانید) در گزارش زیر سعی داریم به صورت مختصر از برنامه ها و ایده های ۳ کاندید نهایی بارسلونا که امروز رای خواهند آورد صحبت کنیم. (اینجا سوابق آنها را ببینید) *خوان لاپورتا او دوران موفقی را در بارسلونا گذارند و توانست جزو مدیران پرافتخار تاریخ آبی اناری ها بدل شود. لاپورتا در مصاحبه و مناظره های خود، خیلی از برنامه های آینده صحبت نکرد و عمیق در خصوص مسایل فوتبالی بحث نکرد. البته باید دانست که او با چهره های ورزشی زیادی آشنا است و به آنها تکیه کرده است. نظر او در خصوص لیونل مسی این است که باید در باشگاه بماند و معتقد است که فقط او می تواند باعث ماندن لیو در بارسلونا شود. لاپورتا در خصوص برنامه اقتصادی برای مدیریت اوضاع وخیم مالی باشگاه نیز اظهار داشته که می تواند درآمد ۱.۴ میلیارد یورویی ایجاد کند اما باید دید چگونه می خواهد بدهی های بارسلونا را در مدت زمان کوتاهی بپردازد. *ویکتور فونت این نامزد بیشتر صحبت هایش را در خصوص پروژه جدید بارسلونا با ژاوی هرناندز بنا کرد. فونت بنا دارد با آمدن ژاوی باعث شود تا لیو مسی در باشگاه بماند. فونت با وجود مشکلات اقتصادی بارسلونا در مناظره های خود اعلام کرده که می خواهد ارلینگ هالند یا کیلیان امباپه را خریداری کند. این مدیر می خواهد درآمد باشگاه را تا سال ۲۰۲۶ به ۱.۴ میلیارد یورو برساند. فونت در مناظره های خود اعلام کرده که مدت زمان مدیریت باید از ۶ سال به ۴ سال کاهش یابد و اگر اتفاقی رخ داد نباید مدیر یا هییت مدیره تغییر کند. *تونی فریشا این مدیر برنامه مشخصی اعلام نکرده ولی می خواهد خرید امباپه یا هالند را عملی سازد. فریشا خواهان ماندن مسی است و ۳ برنامه برای حل مشکلات اقتصادی باشگاه دارد. اول اینکه باید حقوق بازیکنان کاهش یابد، دوم خرید بزرگ انجام نشود و سوم اینکه درآمد باشگاه بیشتر شود. انتهای پیام/'

# %% [markdown]
# # Evaluation and Report

# %%
temp_path = "/kaggle/input/qa-template/questions_template.jsonl"
qa_template = pd.read_json(temp_path, lines=True)
print(qa_template)
# Out:
#      id                                           question  \
# 0    q1  در کدام شهر و ایالت آمریکا ۸ عضو یک خانواده به...
# 1    q2  چه کسی در اجلاس بین‌المللی همکاری‌های علمی و ا...
# 2    q3  شاخص کل بورس اوراق بهادار تهران در پایان معامل...
# 3    q4  چه تعداد مجوز بهداشتی و قرنطینه‌ای حمل دام و ف...
# 4    q5  بسیج جامعه پزشکی برای جبران کمبود پزشک در مناط...
# 5    q6  تعداد بیماران کرونایی بستری در مراکز درمانی گل...
# 6    q7  شهاب عزیزی خادم در مورد اجرای طرح استعدادیابی ...
# 7    q8           موضوع مجموعه تلویزیونی «شبکه کوچک» چیست؟
# 8    q9        کدام مجری پربیننده شبکه فاکس نیوز اخراج شد؟
# 9   q10           ورودی و خروجی آب سد زاینده‌رود چقدر است؟
# 10  q11  در طرح نوروزی پلیس امنیت اقتصادی چند نفر متهم ...
# 11  q12  تیم بسکتبال شیمیدر قم در مرحله مقدماتی چند برد...
# 12  q13  اشیای عتیقه تقلبی کشف شده در مراغه از چه موادی...
# 13  q14                         هدف طرح «بنای ایران» چیست؟
# 14  q15  کدام باشگاه فرانسوی به سردار آزمون پیشنهاد داد...
#
#                                      reference_answer  doc_ids
# 0   این حادثه در شهر انوک در ایالت یوتای آمریکا رخ...  [15956]
# 1   محسن رضایی، معاون اقتصادی رئیس جمهوری، پیشنهاد...  [12585]
# 2   شاخص کل بورس اوراق بهادار تهران با کاهش ۱۸ هزا...   [8144]
# 3   طی سال گذشته ۸۰۰۰ مورد مجوز بهداشتی و قرنطینه‌...  [12462]
# 4   بسیج جامعه پزشکی برای جبران کمبود پزشک، اقدام ...  [10109]
# 5   تعداد بیماران کرونایی بستری در مراکز درمانی گل...   [7123]
# 6   او گفت که اجرای این طرح نشان داد در بخش پایه ا...   [1094]
# 7   این مجموعه مقیاس کوچکی از یک شبکه تلویزیونی اس...   [3604]
# 8   تاکر کارلسون، مجری پربیننده شبکه فاکس نیوز، اخ...   [4339]
# 9   ورودی آب به مخزن سد ۶ مترمکعب بر ثانیه و خروجی...  [16668]
# 10  در این مدت ۷۷۸ نفر متهم دستگیر و تحویل مراجع ق...   [1162]
# 11  تیم شیمیدر قم در مرحله مقدماتی ۱۲ برد از ۱۴ مس...   [7695]
# 12  این اشیای تقلبی از روی آثار واقعی با یونولیت، ...   [1223]
# 13  هدف این طرح مهار پایدار تورم، ایجاد رشد اقتصاد...   [5290]
# 14  باشگاه المپیک مارسی به سردار آزمون پیشنهاد داد...   [7291]

# %%
# Convert the JSON lines into a list of dicts
def get_qas():
    qa_list = []
    qa_len = len(qa_template)
    for i in range(qa_len):
        qa_list.append(dict(qa_template.iloc[i]))
    return qa_list

get_qas()
# Out:
# [{'id': 'q1',
#   'question': 'در کدام شهر و ایالت آمریکا ۸ عضو یک خانواده به دلیل تیراندازی کشته شدند؟',
#   'reference_answer': 'این حادثه در شهر انوک در ایالت یوتای آمریکا رخ داد.',
#   'doc_ids': [15956]},
#  {'id': 'q2',
#   'question': 'چه کسی در اجلاس بین\u200cالمللی همکاری\u200cهای علمی و اقتصادی ایران و کشورهای غرب آفریقا پیشنهاد تاسیس بانک مشترک را داد؟',
#   'reference_answer': 'محسن رضایی، معاون اقتصادی رئیس جمهوری، پیشنهاد تاسیس بانک مشترک ایران و آفریقا را داد.',
#   'doc_ids': [12585]},
#  {'id': 'q3',
#   'question': 'شاخص کل بورس اوراق بهادار تهران در پایان معاملات چقدر کاهش یافت؟',
#   'reference_answer': 'شاخص کل بورس اوراق بهادار تهران با کاهش ۱۸ هزار و ۷۴۶ واحد به رقم یک میلیون و ۱۵۴ هزار و ۷۶۷ واحد رسید.',
#   'doc_ids': [8144]},
#  {'id': 'q4',
#   'question': 'چه تعداد مجوز بهداشتی و قرنطینه\u200cای حمل دام و فرآورده\u200cهای خام دامی طی سال گذشته صادر شده است؟',
#   'reference_answer': 'طی سال گذشته ۸۰۰۰ مورد مجوز بهداشتی و قرنطینه\u200cای حمل انواع دام و فرآورده\u200cهای خام دامی صادر شده است.',
#   'doc_ids': [12462]},
#  {'id': 'q5',
#   'question': 'بسیج جامعه پزشکی برای جبران کمبود پزشک در مناطق بلوچستان چه اقدامی انجام داده است؟',
#   'reference_answer': 'بسیج جامعه پزشکی برای جبران کمبود پزشک، اقدام به راه\u200cاندازی بیمارستان\u200cهای صحرایی کرده است.',
#   'doc_ids': [10109]},
#  {'id': 'q6',
#   'question': 'تعداد بیماران کرونایی بستری در مراکز درمانی گلستان چقدر است؟',
#   'reference_answer': 'تعداد بیماران کرونایی بستری در مراکز درمانی گلستان ۷۳ نفر است.',
#   'doc_ids': [7123]},
#  {'id': 'q7',
#   'question': 'شهاب عزیزی خادم در مورد اجرای طرح استعدادیابی در رده سنی زیر ۱۶ سال چه گفت؟',
#   'reference_answer': 'او گفت که اجرای این طرح نشان داد در بخش پایه استعدادهای بی\u200cنظیری وجود دارد که با حمایت می\u200cتوان شاهد توسعه فوتبال در رده\u200cهای پایه و تیم\u200cهای ملی بود.',
#   'doc_ids': [1094]},
#  {'id': 'q8',
#   'question': 'موضوع مجموعه تلویزیونی «شبکه کوچک» چیست؟',
#   'reference_answer': 'این مجموعه مقیاس کوچکی از یک شبکه تلویزیونی است که در آن شخصیت\u200cهای رئال، عروسکی و انیمیشنی تصمیم می\u200cگیرند یک شبکه تلویزیونی تاسیس کنند.',
#   'doc_ids': [3604]},
#  {'id': 'q9',
#   'question': 'کدام مجری پربیننده شبکه فاکس نیوز اخراج شد؟',
#   'reference_answer': 'تاکر کارلسون، مجری پربیننده شبکه فاکس نیوز، اخراج شد.',
#   'doc_ids': [4339]},
#  {'id': 'q10',
#   'question': 'ورودی و خروجی آب سد زاینده\u200cرود چقدر است؟',
#   'reference_answer': 'ورودی آب به مخزن سد ۶ مترمکعب بر ثانیه و خروجی از سد ۲۳ مترمکعب بر ثانیه است.',
#   'doc_ids': [16668]},
#  {'id': 'q11',
#   'question': 'در طرح نوروزی پلیس امنیت اقتصادی چند نفر متهم دستگیر شدند؟',
#   'reference_answer': 'در این مدت ۷۷۸ نفر متهم دستگیر و تحویل مراجع قضایی شدند.',
#   'doc_ids': [1162]},
#  {'id': 'q12',
#   'question': 'تیم بسکتبال شیمیدر قم در مرحله مقدماتی چند برد کسب کرد؟',
#   'reference_answer': 'تیم شیمیدر قم در مرحله مقدماتی ۱۲ برد از ۱۴ مسابقه کسب کرد.',
#   'doc_ids': [7695]},
#  {'id': 'q13',
#   'question': 'اشیای عتیقه تقلبی کشف شده در مراغه از چه موادی ساخته شده بودند؟',
#   'reference_answer': 'این اشیای تقلبی از روی آثار واقعی با یونولیت، گچ و پلیستر ساخته شده بودند.',
#   'doc_ids': [1223]},
#  {'id': 'q14',
#   'question': 'هدف طرح «بنای ایران» چیست؟',
#   'reference_answer': 'هدف این طرح مهار پایدار تورم، ایجاد رشد اقتصادی و اشتغال، فقرزدایی غیرتورمی، ارتقای جایگاه بین\u200cالمللی اقتصاد کشور و مقابله با فساد است.',
#   'doc_ids': [5290]},
#  {'id': 'q15',
#   'question': 'کدام باشگاه فرانسوی به سردار آزمون پیشنهاد داده است؟',
#   'reference_answer': 'باشگاه المپیک مارسی به سردار آزمون پیشنهاد داده است.',
#   'doc_ids': [7291]}]

# %%
# Evaluating the RAG system and saving the results
import time

qa_list = get_qas()
methods = ['lexical', 'semantic', 'hybrid']
eval_scores = {"lexical": 0, "semantic": 0, "hybrid": 0}
# List of dicts to save the retrieved chunks for each question and other data
eval_data = []

for qa in qa_list:
    print('-'*50)
    print( 'Question: ' + f'{qa["question"]}')
    print( 'True Answer: ' + f'{qa["reference_answer"]}')
    print('-'*50)
    
    for method in methods:
        result, doc_ids, retrieved_chunks = answer(qa['question'], method)
        print('*'*30 + f" ({method.upper()}) " + '*'*30)
        # Check if the true reference document is retrieved
        found_ref = False
        if qa['doc_ids'][0] in doc_ids:
            found_ref = True
            eval_scores[method] += 1
            print("True reference retrieved!")

        else:
            print("Failed to retrieve the true reference!")
            
        print('LLM Answer:')
        print(result)
        data = {'id': qa['id'], 'question': qa['question'], 'ref_answer': qa['reference_answer'],
                'method': method, 'llm_answer': result, 'retrieved_chunks': retrieved_chunks,
                'found_reference': found_ref
               }
        eval_data.append(data)
        # Avoiding the rate limit
        time.sleep(2)
# Out:
# --------------------------------------------------
# Question: در کدام شهر و ایالت آمریکا ۸ عضو یک خانواده به دلیل تیراندازی کشته شدند؟
# True Answer: این حادثه در شهر انوک در ایالت یوتای آمریکا رخ داد.
# --------------------------------------------------
# ****************************** (LEXICAL) ******************************
# True reference retrieved!
# LLM Answer:
# با توجه به اخبار منتشر شده، ۸ عضو یک خانواده به دلیل تیراندازی کشته شدن در شهر انوک، ایالت یوتای آمریکا رخ داده است.
# ****************************** (SEMANTIC) ******************************
# True reference retrieved!
# LLM Answer:
# بر اساس گزارش‌ها، در یک شهر نامنوشته در ایالت یوتای آمریکا، ۸ عضو یک خانواده به دلیل تیراندازی کشته شدند، اما نام شهر مشخص نیست.
# ****************************** (HYBRID) ******************************
# True reference retrieved!
# LLM Answer:
# بر اساس اخبار منتشر شده، این حادثه در شهر "انوک"، ایالت "یوتا" در آمریکا رخ داد.
# --------------------------------------------------
# Question: چه کسی در اجلاس بین‌المللی همکاری‌های علمی و اقتصادی ایران و کشورهای غرب آفریقا پیشنهاد تاسیس بانک مشترک را داد؟
# True Answer: محسن رضایی، معاون اقتصادی رئیس جمهوری، پیشنهاد تاسیس بانک مشترک ایران و آفریقا را داد.
# --------------------------------------------------
# ****************************** (LEXICAL) ******************************
# True reference retrieved!
# LLM Answer:
# محسن رضایی معاون اقتصادی رییس جمهور، در اجلاس بین‌المللی همکاری‌های علمی و اقتصادی ایران و کشورهای غرب آفریقا تبیین کرد که ایجاد بانک مشترک ایران و آفریقا سرآغاز خوبی برای توسعه روابط خواهد بود.
# ****************************** (SEMANTIC) ******************************
# True reference retrieved!
# LLM Answer:
# محسن رضایی، معاون اقتصادی رییس جمهوری. او در این اجلاس اظهار کرد: ایجاد بانک مشترک ایران و آفریقا سرآغاز خوبی برای توسعه روابط فی مابین است.
# ****************************** (HYBRID) ******************************
# True reference retrieved!
# LLM Answer:
# محسن رضایی معاون اقتصادی رییس جمهور، پیشنهاد تاسیس بانک مشترک ایران و آفریقا را داد.
# --------------------------------------------------
# Question: شاخص کل بورس اوراق بهادار تهران در پایان معاملات چقدر کاهش یافت؟
# True Answer: شاخص کل بورس اوراق بهادار تهران با کاهش ۱۸ هزار و ۷۴۶ واحد به رقم یک میلیون و ۱۵۴ هزار و ۷۶۷ واحد رسید.
# --------------------------------------------------
# ****************************** (LEXICAL) ******************************
# True reference retrieved!
# LLM Answer:
# شاخص کل بورس اوراق بهادار تهران در پایان معاملات با کاهش ۹۱۵۱ واحد به رقم یک میلیون و ۲۴۰ هزار و ۷۵۸ واحد رسید.
# ****************************** (SEMANTIC) ******************************
# True reference retrieved!
# LLM Answer:
# شاخص کل بورس اوراق بهادار تهران در پایان معاملات در بین مختلف موارد، ۲۵۰۶ واحد به ۱ میلیارد و ۵۳۹ هزار میلیارد تومان رسید. همچنین ۷۳۰۶، ۱۸ هزار و ۷۴۶، ۷۷۱۶و ۹۵ هزار و ۴۰ واحد کاهش یافت. به این معنی که پاسخ به سوال، به‌طور کلی ۹۵ هزار و ۴۰ واحد کاهش یافت.
# ****************************** (HYBRID) ******************************
# True reference retrieved!
# LLM Answer:
# بهترین پاسخ این است که شاخص کل بورس اوراق بهادار تهران در روز آخر در حالیکه ریزش سنگین داشت 95,000 و 40 واحد کاهش یافت. به طور کلی در چند روز گذشته شاخص کل به طور میانگین بین 7000 تا 18000 واحد کاهش یافته است. در روزهای قبلی نیز به ترتیب این تعداد بوده است:
# - روز قبل از آن: 7306 واحد
# - روز قبل از آن: 18,746 واحد
# - روز قبل از آن : 7716 واحد
# - روز قبل از آن : 25,006 واحد (در روز ریزش سنگین)
# --------------------------------------------------
# Question: چه تعداد مجوز بهداشتی و قرنطینه‌ای حمل دام و فرآورده‌های خام دامی طی سال گذشته صادر شده است؟
# True Answer: طی سال گذشته ۸۰۰۰ مورد مجوز بهداشتی و قرنطینه‌ای حمل انواع دام و فرآورده‌های خام دامی صادر شده است.
# --------------------------------------------------
# ****************************** (LEXICAL) ******************************
# True reference retrieved!
# LLM Answer:
# براساس اطلاعات منتشر شده، طی سال گذشته، ۸۰۰۰ مورد مجوز بهداشتی و قرنطینه‌ای حمل انواع دام و فرآورده‌های خام دامی توسط کاربران سامانه قرنطینه و امنیت زیستی دامپزشکی شهرستان صادر شده است.
# ****************************** (SEMANTIC) ******************************
# True reference retrieved!
# LLM Answer:
# بر اساس گزارش بهزاد صادقی، به زودی مدیرکل اداره دامپزشکی، ۸۰۰۰ مجوز بهداشتی و قرنطینه‌ای حمل انواع دام و فرآورده‌های خام دامی طی سال گذشته توسط کاربران سامانه قرنطینه و امنیت زیستی دامپزشکی صادر شده است.
# ****************************** (HYBRID) ******************************
# True reference retrieved!
# LLM Answer:
# در سال گذشته ۸۰۰۰ مجوز بهداشتی و قرنطینه‌ای حمل دام و فرآورده‌های خام دامی توسط کاربران سامانه قرنطینه و امنیت زیستی دامپزشکی شهرستان صادر شده است.
# --------------------------------------------------
# Question: بسیج جامعه پزشکی برای جبران کمبود پزشک در مناطق بلوچستان چه اقدامی انجام داده است؟
# True Answer: بسیج جامعه پزشکی برای جبران کمبود پزشک، اقدام به راه‌اندازی بیمارستان‌های صحرایی کرده است.
# --------------------------------------------------
# ****************************** (LEXICAL) ******************************
# True reference retrieved!
# LLM Answer:
# بسیج جامعه پزشکی در سطح استان سیستان و بلوچستان، به جبران کمبود پزشک تلاش کرده است. به عنوان بخشی از این تلاش، بیمارستان‌های صحرایی در قرقری شهرستان هیرمند و کشتگان شهرستان سراوان تأسیس شده است. همچنین، تیم‌های درمانی چند تخصصی به مناطق مختلف اعزام شده است. یکی از مواردی که در آینده نزدیک از سوی بسیج جامعه پزشکی درحال ابلاغ است، اعزام تیم چند تخصصی به شهرستان زهک می‌باشد که این تیم شامل ۸ متخصص است و برای انجام عملیات جراحی چشم عمل می‌کند.
# ****************************** (SEMANTIC) ******************************
# Failed to retrieve the true reference!
# LLM Answer:
# بسیج جامع پزشکی در استان چهارمحال و بختیاری، ۱۴ تیم را به مناطق مختلف اعزام کرده است تا خدمات بهداشتی-درمانی و آموزشی را ارایه کند. این تیم‌ها در بخش‌های مختلف از جمله بهداشت، درمان، آموزش، مشاوره روانشناسی و دندانپزشکی خدمات ارائه شده‌اند.
# ****************************** (HYBRID) ******************************
# True reference retrieved!
# LLM Answer:
# بسیج جامعه پزشکی در راستای جبران کمبود پزشک در مناطق بلوچستان، بیمارستان‌های صحرایی را راه‌اندازی کرده است. این بیمارستان‌های صحرایی در مناطق قرقری شهرستان هیرمند و کشتگان شهرستان سراوان تاسیس شده‌اند.
# --------------------------------------------------
# Question: تعداد بیماران کرونایی بستری در مراکز درمانی گلستان چقدر است؟
# True Answer: تعداد بیماران کرونایی بستری در مراکز درمانی گلستان ۷۳ نفر است.
# --------------------------------------------------
# ****************************** (LEXICAL) ******************************
# True reference retrieved!
# LLM Answer:
# طبق آخرین گزارش، تعداد بیماران کرونایی بستری در مراکز درمانی گلستان 117 بیمار است.
# ****************************** (SEMANTIC) ******************************
# True reference retrieved!
# LLM Answer:
# در آخرین گزارش، تعداد بیماران کرونایی بستری در مراکز درمانی و بیمارستان های گلستان به ۱۱۷ نفر رسیده است.
# ****************************** (HYBRID) ******************************
# True reference retrieved!
# LLM Answer:
# بر اساس گزارش های اخیر، تعداد بیماران کرونایی بستری در مراکز درمانی گلستان به ۱۱۷ نفر رسیده است.
# --------------------------------------------------
# Question: شهاب عزیزی خادم در مورد اجرای طرح استعدادیابی در رده سنی زیر ۱۶ سال چه گفت؟
# True Answer: او گفت که اجرای این طرح نشان داد در بخش پایه استعدادهای بی‌نظیری وجود دارد که با حمایت می‌توان شاهد توسعه فوتبال در رده‌های پایه و تیم‌های ملی بود.
# --------------------------------------------------
# ****************************** (LEXICAL) ******************************
# True reference retrieved!
# LLM Answer:
# شهاب عزیزی خادم در مورد اجرای طرح استعدادیابی در رده سنی زیر ۱۶ سال گمانه زده است که: "خوشبختانه اجرای این طرح نشان داد در بخش پایه استعدادهای بی نظیری وجود دارد که بدون شک با پوشش و حمایت می توان در آینده، شاهد توسعه بیش ازپیش فوتبال در رده های پایه و تیم های ملی بود."
# ****************************** (SEMANTIC) ******************************
# Failed to retrieve the true reference!
# LLM Answer:
# با توجه به وجود یک قسمت در اخبار رخ داده در خراسان جنوبی که در آنجا بحث استعدادیابی یا استعداد یابی به طور کامل صورت نگرفته است اما در بخش خبر مربوط به وزنه برداری استان کردستان می گوید: وزنه برداری استان در مقطع پایه به خوبی عمل شده و در این مقطع پایه حضور موفق در المپیاد استعدادهای برتر کشور داشته ایم. اما در مقطع بزرگسالان هنوز جای کار بسیار هست و باید سال ها تلاش کنیم که با حضور این نوجوانان در مقاطع بالاتر حرف هایی برای گفتن داشته باشیم.
# ****************************** (HYBRID) ******************************
# True reference retrieved!
# LLM Answer:
# شهاب عزیزی خادم در مورد اجرای طرح استعدادیابی در رده سنی زیر ۱۶ سال گفت: خوشبختانه اجرای این طرح نشان داد که در بخش پایه استعدادهای بی نظیری وجود دارد، که بدون شک با پوشش و حمایت می توان در آینده، شاهد توسعه بیش ازپیش فوتبال در رده های پایه و تیم های ملی بود.
# --------------------------------------------------
# Question: موضوع مجموعه تلویزیونی «شبکه کوچک» چیست؟
# True Answer: این مجموعه مقیاس کوچکی از یک شبکه تلویزیونی است که در آن شخصیت‌های رئال، عروسکی و انیمیشنی تصمیم می‌گیرند یک شبکه تلویزیونی تاسیس کنند.
# --------------------------------------------------
# ****************************** (LEXICAL) ******************************
# True reference retrieved!
# LLM Answer:
# مجموعه تلویزیونی «شبکه کوچک» داستان شخصیت های مختلفی است که تصمیم به تاسیس یک شبکه تلویزیونی می گیرند و پس از آن تصمیم می گیرند که با مخاطبان ارتباط برقرار کنند و روندی تعاملی با آنها داشته باشند.
# ****************************** (SEMANTIC) ******************************
# True reference retrieved!
# LLM Answer:
# مجموعه تلویزیونی «شبکه کوچک» در مورد تاسیس و اداره یک شبکه تلویزیونی است که شخصیت های ریال، عروسکی و انیمیشنی با هم این شبکه را تشکیل می دهند.
# ****************************** (HYBRID) ******************************
# True reference retrieved!
# LLM Answer:
# مجموعه تلویزیونی «شبکه کوچک» درباره création یک شبکه تلویزیونی و نقش شخصیت های مختلف در اداره و تولید_CONTENT شبکه تلویزیونی است.
# --------------------------------------------------
# Question: کدام مجری پربیننده شبکه فاکس نیوز اخراج شد؟
# True Answer: تاکر کارلسون، مجری پربیننده شبکه فاکس نیوز، اخراج شد.
# --------------------------------------------------
# ****************************** (LEXICAL) ******************************
# True reference retrieved!
# LLM Answer:
# تاکر کارلسون مجری پربیننده شبکه فاکس نیوز به گفته رسانه ها اخراج شد.
# ****************************** (SEMANTIC) ******************************
# True reference retrieved!
# LLM Answer:
# تاکر کارلسون مجری پربیننده شبکه فاکس نیوز آمریکا، پس از کمتر از یک هفته پس از توافق شبکه فاکس نیوز با یکی از شرکت های حقوقی، اخراج شد.
# ****************************** (HYBRID) ******************************
# True reference retrieved!
# LLM Answer:
# مجری پربیننده شبکه فاکس نیوز، "تاکر کارلسون" اخراج شد.
# --------------------------------------------------
# Question: ورودی و خروجی آب سد زاینده‌رود چقدر است؟
# True Answer: ورودی آب به مخزن سد ۶ مترمکعب بر ثانیه و خروجی از سد ۲۳ مترمکعب بر ثانیه است.
# --------------------------------------------------
# ****************************** (LEXICAL) ******************************
# True reference retrieved!
# LLM Answer:
# میزان ورودی آب به سد زاینده‌رود ۱۱۳ متر مکعب بر ثانیه و میزان خروجی از سد ۴۸ متر مکعب بر ثانیه است.
# ****************************** (SEMANTIC) ******************************
# True reference retrieved!
# LLM Answer:
# ورودی آب به سد زاینده‌رود به ۱۱۳ مترمکعب بر ثانیه و خروجی از سد ۴۸ مترمکعب بر ثانیه رسیده است.
# ****************************** (HYBRID) ******************************
# True reference retrieved!
# LLM Answer:
# میزان ورودی آب به سد زاینده رود ۶ مترمکعب بر ثانیه و خروجی آن ۲۳ مترمکعب بر ثانیه است.
# --------------------------------------------------
# Question: در طرح نوروزی پلیس امنیت اقتصادی چند نفر متهم دستگیر شدند؟
# True Answer: در این مدت ۷۷۸ نفر متهم دستگیر و تحویل مراجع قضایی شدند.
# --------------------------------------------------
# ****************************** (LEXICAL) ******************************
# True reference retrieved!
# LLM Answer:
# به根據 گزارش‌های موجود، در این مدت (پس از شروع تعطیلات نوروزی تا به امروز)  ۷۷۸  متهم دستگیر شدند.
# ****************************** (SEMANTIC) ******************************
# True reference retrieved!
# LLM Answer:
# سردار حسین رحیمی رییس پلیس امنیت اقتصادی گفت در طرح نوروزی، ۸۹ نفر متهم در زمینه مبارزه با احتکار و اخلال در نظام اقتصادی کشور و همچنین ۶۸۹ نفر متهم در زمینه مبارزه با قاچاق کالا و ارز دستگیر شدند.
# ****************************** (HYBRID) ******************************
# True reference retrieved!
# LLM Answer:
# بطور کلی در طرح نوروزی پلیس امنیت اقتصادی، تعداد متهمان دستگیر شده ۷۷۸ نفر اعلام شده است، همچنین ۸۹ نفر متهم دستگیر شدند، به ارزش تقریبی ۸ هزار میلیارد ریال.
# --------------------------------------------------
# Question: تیم بسکتبال شیمیدر قم در مرحله مقدماتی چند برد کسب کرد؟
# True Answer: تیم شیمیدر قم در مرحله مقدماتی ۱۲ برد از ۱۴ مسابقه کسب کرد.
# --------------------------------------------------
# ****************************** (LEXICAL) ******************************
# True reference retrieved!
# LLM Answer:
# بر اساس گزارش های موجود، تیم بسکتبال شیمیدر قم در مرحله مقدماتی لیگ برتر بسکتبال ۱۲ برد از ۱۴ مسابقه و هشت برد از نُه مسابقه کسب کرده است.
# ****************************** (SEMANTIC) ******************************
# Failed to retrieve the true reference!
# LLM Answer:
# تیم بسکتبال شیمیدر قم در مرحله مقدماتی هشت برد کسب کرد.
# ****************************** (HYBRID) ******************************
# Failed to retrieve the true reference!
# LLM Answer:
# برندهٔ مسابقه مقابل شهرداری بندرعباس، شیمیدر قم با هشت برد، یک باخت و ۱۷ امتیاز در رده دوم گروه نخست قرار دارد. همچنین در هفته یازدهم شیمیدر قم مقابل شهرداری بندرعباس به برد ۹۶ بر ۶۷ رسید و همچنین در هفته دهم به برد ۸۴ بر ۷۸، در هفته نهم به برد ۷۹ بر ۵۸، در هفته هشتم به برد ۶۶ بر ۶۳، در هفته هفتم به برد ۹۹ بر ۴۱، هفته ششم به برد ۷۳ بر ۶۱، در هفته پنجم به برد ۸۱ بر ۶۴، در هفته چهارم به برد۹۱ بر ۷۲ و در هفته سوم برد مقابل تیم مهرام تهران را نیز به دست آورد.
# --------------------------------------------------
# Question: اشیای عتیقه تقلبی کشف شده در مراغه از چه موادی ساخته شده بودند؟
# True Answer: این اشیای تقلبی از روی آثار واقعی با یونولیت، گچ و پلیستر ساخته شده بودند.
# --------------------------------------------------
# ****************************** (LEXICAL) ******************************
# True reference retrieved!
# LLM Answer:
# بر اساس اعلام فارسی، اشیای عتیقه تقلبی کشف شده در مراغه از روی آثار واقعی با استفاده از یونولیت، گچ و پلیستر ساخته شده اند.
# ****************************** (SEMANTIC) ******************************
# True reference retrieved!
# LLM Answer:
# اشیای عتیقه تقلبی کشف شده در مراغه از روی آثار واقعی با یونولیت، گچ و پلیستر ساخته شده بودند.
# ****************************** (HYBRID) ******************************
# True reference retrieved!
# LLM Answer:
# اشیای عتیقه تقلبی کشف شده در مراغه از روی آثار واقعی با استفاده از موادی مانند یونولیت، گچ و پلیستر ساخته شده است.
# --------------------------------------------------
# Question: هدف طرح «بنای ایران» چیست؟
# True Answer: هدف این طرح مهار پایدار تورم، ایجاد رشد اقتصادی و اشتغال، فقرزدایی غیرتورمی، ارتقای جایگاه بین‌المللی اقتصاد کشور و مقابله با فساد است.
# --------------------------------------------------
# ****************************** (LEXICAL) ******************************
# True reference retrieved!
# LLM Answer:
# مرحله اول برای پاسخ به این سوال به متن قبلی می بینیم که در این متن هدف طرح «بنای ایران» را آورده است. هدف طرح «بنای ایران» مهار پایدار تورم، ایجاد رشد اقتصادی و اشتغال، فقرزدایی غیرتورمی، ارتقای جایگاه بین المللی اقتصاد کشور و مقابله با فساد است.
#
# در ادامه و برای پاسخ به این سوال، از متن دوم می بینیم که اشاره‌ای به این طرح نشده است.  سپس متن سوم مربوط به طرح «بنای ایران» نیست.
#
# بنابراین، از متن اول و چهارم استفاده می‌کنیم تا پاسخ به این سوال به دست آید.
#
# پاسخ: هدف طرح «بنای ایران» مهار پایدار تورم، ایجاد رشد اقتصادی و اشتغال، فقرزدایی غیرتورمی، ارتقای جایگاه بین المللی اقتصاد کشور و مقابله با فساد است.
# ****************************** (SEMANTIC) ******************************
# Failed to retrieve the true reference!
# LLM Answer:
# براساس متن فوق، هدف دولت از تشکیل ایران قوی، با اتکا به تولید ملي است. دولت با تشکیل یک ائتلاف با تولیدکنندگان، کارآفرینان و کارگران، به هدف مشترک خود یعنی تشکیل ایران強 می رسد.
# ****************************** (HYBRID) ******************************
# True reference retrieved!
# LLM Answer:
# طرح «بنای ایران» با هدف مهار پایدار تورم، ایجاد رشد اقتصادی و اشتغال، فقرزدایی غیرتورمی، ارتقای جایگاه بین‌المللی اقتصاد کشور و مقابله با فساد تدوین شده است.
# --------------------------------------------------
# Question: کدام باشگاه فرانسوی به سردار آزمون پیشنهاد داده است؟
# True Answer: باشگاه المپیک مارسی به سردار آزمون پیشنهاد داده است.
# --------------------------------------------------
# ****************************** (LEXICAL) ******************************
# True reference retrieved!
# LLM Answer:
# بر اساس خبرهای داده شده، المپیک مارسی و لیون دو باشگاه فرانسوی هستند که به سردار آزمون پیشنهاد داده‌اند.
# ****************************** (SEMANTIC) ******************************
# Failed to retrieve the true reference!
# LLM Answer:
# بر اساس اطلاعات موجود در این خبر، هیچ باشگاه فرانسوی‌ای به سردار آزمون پیشنهاد داده ناتمام نیست.
# ****************************** (HYBRID) ******************************
# Failed to retrieve the true reference!
# LLM Answer:
# از مطالب موجود در خبرها معلوم نمی‌شود که باشگاهی به جز لیون به سردار آزمون پیشنهاد داده باشد.

# %%
eval_df = pd.DataFrame(eval_data)
print(eval_df)
# Out:
#      id                                           question  \
# 0    q1  در کدام شهر و ایالت آمریکا ۸ عضو یک خانواده به...
# 1    q1  در کدام شهر و ایالت آمریکا ۸ عضو یک خانواده به...
# 2    q1  در کدام شهر و ایالت آمریکا ۸ عضو یک خانواده به...
# 3    q2  چه کسی در اجلاس بین‌المللی همکاری‌های علمی و ا...
# 4    q2  چه کسی در اجلاس بین‌المللی همکاری‌های علمی و ا...
# 5    q2  چه کسی در اجلاس بین‌المللی همکاری‌های علمی و ا...
# 6    q3  شاخص کل بورس اوراق بهادار تهران در پایان معامل...
# 7    q3  شاخص کل بورس اوراق بهادار تهران در پایان معامل...
# 8    q3  شاخص کل بورس اوراق بهادار تهران در پایان معامل...
# 9    q4  چه تعداد مجوز بهداشتی و قرنطینه‌ای حمل دام و ف...
# 10   q4  چه تعداد مجوز بهداشتی و قرنطینه‌ای حمل دام و ف...
# 11   q4  چه تعداد مجوز بهداشتی و قرنطینه‌ای حمل دام و ف...
# 12   q5  بسیج جامعه پزشکی برای جبران کمبود پزشک در مناط...
# 13   q5  بسیج جامعه پزشکی برای جبران کمبود پزشک در مناط...
# 14   q5  بسیج جامعه پزشکی برای جبران کمبود پزشک در مناط...
# 15   q6  تعداد بیماران کرونایی بستری در مراکز درمانی گل...
# 16   q6  تعداد بیماران کرونایی بستری در مراکز درمانی گل...
# 17   q6  تعداد بیماران کرونایی بستری در مراکز درمانی گل...
# 18   q7  شهاب عزیزی خادم در مورد اجرای طرح استعدادیابی ...
# 19   q7  شهاب عزیزی خادم در مورد اجرای طرح استعدادیابی ...
# 20   q7  شهاب عزیزی خادم در مورد اجرای طرح استعدادیابی ...
# 21   q8           موضوع مجموعه تلویزیونی «شبکه کوچک» چیست؟
# 22   q8           موضوع مجموعه تلویزیونی «شبکه کوچک» چیست؟
# 23   q8           موضوع مجموعه تلویزیونی «شبکه کوچک» چیست؟
# 24   q9        کدام مجری پربیننده شبکه فاکس نیوز اخراج شد؟
# 25   q9        کدام مجری پربیننده شبکه فاکس نیوز اخراج شد؟
# 26   q9        کدام مجری پربیننده شبکه فاکس نیوز اخراج شد؟
# 27  q10           ورودی و خروجی آب سد زاینده‌رود چقدر است؟
# 28  q10           ورودی و خروجی آب سد زاینده‌رود چقدر است؟
# 29  q10           ورودی و خروجی آب سد زاینده‌رود چقدر است؟
# 30  q11  در طرح نوروزی پلیس امنیت اقتصادی چند نفر متهم ...
# 31  q11  در طرح نوروزی پلیس امنیت اقتصادی چند نفر متهم ...
# 32  q11  در طرح نوروزی پلیس امنیت اقتصادی چند نفر متهم ...
# 33  q12  تیم بسکتبال شیمیدر قم در مرحله مقدماتی چند برد...
# 34  q12  تیم بسکتبال شیمیدر قم در مرحله مقدماتی چند برد...
# 35  q12  تیم بسکتبال شیمیدر قم در مرحله مقدماتی چند برد...
# 36  q13  اشیای عتیقه تقلبی کشف شده در مراغه از چه موادی...
# 37  q13  اشیای عتیقه تقلبی کشف شده در مراغه از چه موادی...
# 38  q13  اشیای عتیقه تقلبی کشف شده در مراغه از چه موادی...
# 39  q14                         هدف طرح «بنای ایران» چیست؟
# 40  q14                         هدف طرح «بنای ایران» چیست؟
# 41  q14                         هدف طرح «بنای ایران» چیست؟
# 42  q15  کدام باشگاه فرانسوی به سردار آزمون پیشنهاد داد...
# 43  q15  کدام باشگاه فرانسوی به سردار آزمون پیشنهاد داد...
# 44  q15  کدام باشگاه فرانسوی به سردار آزمون پیشنهاد داد...
#
#                                            ref_answer    method  \
# 0   این حادثه در شهر انوک در ایالت یوتای آمریکا رخ...   lexical
# 1   این حادثه در شهر انوک در ایالت یوتای آمریکا رخ...  semantic
# 2   این حادثه در شهر انوک در ایالت یوتای آمریکا رخ...    hybrid
# 3   محسن رضایی، معاون اقتصادی رئیس جمهوری، پیشنهاد...   lexical
# 4   محسن رضایی، معاون اقتصادی رئیس جمهوری، پیشنهاد...  semantic
# 5   محسن رضایی، معاون اقتصادی رئیس جمهوری، پیشنهاد...    hybrid
# 6   شاخص کل بورس اوراق بهادار تهران با کاهش ۱۸ هزا...   lexical
# 7   شاخص کل بورس اوراق بهادار تهران با کاهش ۱۸ هزا...  semantic
# 8   شاخص کل بورس اوراق بهادار تهران با کاهش ۱۸ هزا...    hybrid
# 9   طی سال گذشته ۸۰۰۰ مورد مجوز بهداشتی و قرنطینه‌...   lexical
# 10  طی سال گذشته ۸۰۰۰ مورد مجوز بهداشتی و قرنطینه‌...  semantic
# 11  طی سال گذشته ۸۰۰۰ مورد مجوز بهداشتی و قرنطینه‌...    hybrid
# 12  بسیج جامعه پزشکی برای جبران کمبود پزشک، اقدام ...   lexical
# 13  بسیج جامعه پزشکی برای جبران کمبود پزشک، اقدام ...  semantic
# 14  بسیج جامعه پزشکی برای جبران کمبود پزشک، اقدام ...    hybrid
# 15  تعداد بیماران کرونایی بستری در مراکز درمانی گل...   lexical
# 16  تعداد بیماران کرونایی بستری در مراکز درمانی گل...  semantic
# 17  تعداد بیماران کرونایی بستری در مراکز درمانی گل...    hybrid
# 18  او گفت که اجرای این طرح نشان داد در بخش پایه ا...   lexical
# 19  او گفت که اجرای این طرح نشان داد در بخش پایه ا...  semantic
# 20  او گفت که اجرای این طرح نشان داد در بخش پایه ا...    hybrid
# 21  این مجموعه مقیاس کوچکی از یک شبکه تلویزیونی اس...   lexical
# 22  این مجموعه مقیاس کوچکی از یک شبکه تلویزیونی اس...  semantic
# 23  این مجموعه مقیاس کوچکی از یک شبکه تلویزیونی اس...    hybrid
# 24  تاکر کارلسون، مجری پربیننده شبکه فاکس نیوز، اخ...   lexical
# 25  تاکر کارلسون، مجری پربیننده شبکه فاکس نیوز، اخ...  semantic
# 26  تاکر کارلسون، مجری پربیننده شبکه فاکس نیوز، اخ...    hybrid
# 27  ورودی آب به مخزن سد ۶ مترمکعب بر ثانیه و خروجی...   lexical
# 28  ورودی آب به مخزن سد ۶ مترمکعب بر ثانیه و خروجی...  semantic
# 29  ورودی آب به مخزن سد ۶ مترمکعب بر ثانیه و خروجی...    hybrid
# 30  در این مدت ۷۷۸ نفر متهم دستگیر و تحویل مراجع ق...   lexical
# 31  در این مدت ۷۷۸ نفر متهم دستگیر و تحویل مراجع ق...  semantic
# 32  در این مدت ۷۷۸ نفر متهم دستگیر و تحویل مراجع ق...    hybrid
# 33  تیم شیمیدر قم در مرحله مقدماتی ۱۲ برد از ۱۴ مس...   lexical
# 34  تیم شیمیدر قم در مرحله مقدماتی ۱۲ برد از ۱۴ مس...  semantic
# 35  تیم شیمیدر قم در مرحله مقدماتی ۱۲ برد از ۱۴ مس...    hybrid
# 36  این اشیای تقلبی از روی آثار واقعی با یونولیت، ...   lexical
# 37  این اشیای تقلبی از روی آثار واقعی با یونولیت، ...  semantic
# 38  این اشیای تقلبی از روی آثار واقعی با یونولیت، ...    hybrid
# 39  هدف این طرح مهار پایدار تورم، ایجاد رشد اقتصاد...   lexical
# 40  هدف این طرح مهار پایدار تورم، ایجاد رشد اقتصاد...  semantic
# 41  هدف این طرح مهار پایدار تورم، ایجاد رشد اقتصاد...    hybrid
# 42  باشگاه المپیک مارسی به سردار آزمون پیشنهاد داد...   lexical
# 43  باشگاه المپیک مارسی به سردار آزمون پیشنهاد داد...  semantic
# 44  باشگاه المپیک مارسی به سردار آزمون پیشنهاد داد...    hybrid
#
#                                            llm_answer  \
# 0   با توجه به اخبار منتشر شده، ۸ عضو یک خانواده ب...
# 1   بر اساس گزارش‌ها، در یک شهر نامنوشته در ایالت ...
# 2   بر اساس اخبار منتشر شده، این حادثه در شهر "انو...
# 3   محسن رضایی معاون اقتصادی رییس جمهور، در اجلاس ...
# 4   محسن رضایی، معاون اقتصادی رییس جمهوری. او در ا...
# 5   محسن رضایی معاون اقتصادی رییس جمهور، پیشنهاد ت...
# 6   شاخص کل بورس اوراق بهادار تهران در پایان معامل...
# 7   شاخص کل بورس اوراق بهادار تهران در پایان معامل...
# 8   بهترین پاسخ این است که شاخص کل بورس اوراق بهاد...
# 9   براساس اطلاعات منتشر شده، طی سال گذشته، ۸۰۰۰ م...
# 10  بر اساس گزارش بهزاد صادقی، به زودی مدیرکل ادار...
# 11  در سال گذشته ۸۰۰۰ مجوز بهداشتی و قرنطینه‌ای حم...
# 12  بسیج جامعه پزشکی در سطح استان سیستان و بلوچستا...
# 13  بسیج جامع پزشکی در استان چهارمحال و بختیاری، ۱...
# 14  بسیج جامعه پزشکی در راستای جبران کمبود پزشک در...
# 15  طبق آخرین گزارش، تعداد بیماران کرونایی بستری د...
# 16  در آخرین گزارش، تعداد بیماران کرونایی بستری در...
# 17  بر اساس گزارش های اخیر، تعداد بیماران کرونایی ...
# 18  شهاب عزیزی خادم در مورد اجرای طرح استعدادیابی ...
# 19  با توجه به وجود یک قسمت در اخبار رخ داده در خر...
# 20  شهاب عزیزی خادم در مورد اجرای طرح استعدادیابی ...
# 21  مجموعه تلویزیونی «شبکه کوچک» داستان شخصیت های ...
# 22  مجموعه تلویزیونی «شبکه کوچک» در مورد تاسیس و ا...
# 23  مجموعه تلویزیونی «شبکه کوچک» درباره création ی...
# 24  تاکر کارلسون مجری پربیننده شبکه فاکس نیوز به گ...
# 25  تاکر کارلسون مجری پربیننده شبکه فاکس نیوز آمری...
# 26  مجری پربیننده شبکه فاکس نیوز، "تاکر کارلسون" ا...
# 27  میزان ورودی آب به سد زاینده‌رود ۱۱۳ متر مکعب ب...
# 28  ورودی آب به سد زاینده‌رود به ۱۱۳ مترمکعب بر ثا...
# 29  میزان ورودی آب به سد زاینده رود ۶ مترمکعب بر ث...
# 30  به根據 گزارش‌های موجود، در این مدت (پس از شروع ت...
# 31  سردار حسین رحیمی رییس پلیس امنیت اقتصادی گفت د...
# 32  بطور کلی در طرح نوروزی پلیس امنیت اقتصادی، تعد...
# 33  بر اساس گزارش های موجود، تیم بسکتبال شیمیدر قم...
# 34  تیم بسکتبال شیمیدر قم در مرحله مقدماتی هشت برد...
# 35  برندهٔ مسابقه مقابل شهرداری بندرعباس، شیمیدر ق...
# 36  بر اساس اعلام فارسی، اشیای عتیقه تقلبی کشف شده...
# 37  اشیای عتیقه تقلبی کشف شده در مراغه از روی آثار...
# 38  اشیای عتیقه تقلبی کشف شده در مراغه از روی آثار...
# 39  مرحله اول برای پاسخ به این سوال به متن قبلی می...
# 40  براساس متن فوق، هدف دولت از تشکیل ایران قوی، ب...
# 41  طرح «بنای ایران» با هدف مهار پایدار تورم، ایجا...
# 42  بر اساس خبرهای داده شده، المپیک مارسی و لیون د...
# 43  بر اساس اطلاعات موجود در این خبر، هیچ باشگاه ف...
# 44  از مطالب موجود در خبرها معلوم نمی‌شود که باشگا...
#
#                                      retrieved_chunks  found_reference
# 0   [ خشونت مسلحانه در آمریکا جان ۸ عضو خانواده را...             True
# 1   [ خشونت مسلحانه در آمریکا جان ۸ عضو خانواده را...             True
# 2   [ خشونت مسلحانه در آمریکا جان ۸ عضو خانواده را...             True
# 3   [بانک مشترک ایران و آفریقا تاسیس می‌شود/ تجارت...             True
# 4   [معاون بانک ایران زمین: موفقیت سازمان در گرو ف...             True
# 5   [بانک مشترک ایران و آفریقا تاسیس می‌شود/ تجارت...             True
# 6   [کاهش 9151 واحدی شاخص بورس تهران/ ارزش معاملات...             True
# 7   [ ادامه روند نزولی شاخص کل بورس +نقشه\nبه گزار...             True
# 8   [ ادامه روند نزولی شاخص کل بورس +نقشه\nبه گزار...             True
# 9   [ صدور ۸۰۰۰ مجوز بهداشتی، قرنطینه‌ای حمل دام و...             True
# 10  [ صدور ۸۰۰۰ مجوز بهداشتی، قرنطینه‌ای حمل دام و...             True
# 11  [ صدور ۸۰۰۰ مجوز بهداشتی، قرنطینه‌ای حمل دام و...             True
# 12  [هار زابل تجلیل شده است. وی با اشاره به اینکه ...             True
# 13  [ر شهرستان دیر ۳۸ نفر نیروی تخصصی بهداشت و درم...            False
# 14  [اعزام تیم‌های بسیج جامعه پزشکی به مناطق محروم...             True
# 15  [۷۳ بیمار کرونایی در مراکز درمانی گلستان بستری...             True
# 16  [۷۳ بیمار کرونایی در مراکز درمانی گلستان بستری...             True
# 17  [۷۳ بیمار کرونایی در مراکز درمانی گلستان بستری...             True
# 18  [عزیزی خادم: کره جنوبی با آن اقتصاد با پرواز ا...             True
# 19  [مسابقات لیگ وزنه‌برداری کردستان برگزار می‌شود...            False
# 20  [بود. رییس فدراسیون فوتبال ادامه داد: به آینده...             True
# 21  [آغاز پخش «شبکه کوچک» در نوروز/ مقیاس کوچکی از...             True
# 22  [فرادی که سابقه نمایندگی داشته اند شهودا درک م...             True
# 23  [آغاز پخش «شبکه کوچک» در نوروز/ مقیاس کوچکی از...             True
# 24  [ زلزله در رسانه های آمریکا؛ اخراج مجریان فاکس...             True
# 25  [ نزد مخاطبان کاهش یافته است. اخراج مدیر اجرای...             True
# 26  [ زلزله در رسانه های آمریکا؛ اخراج مجریان فاکس...             True
# 27  [ورودی آب به سد زاینده رود به ۱۱۳ مترمکعب بر ث...             True
# 28  [ورودی آب به سد زاینده رود به ۱۱۳ مترمکعب بر ث...             True
# 29  [ورودی آب به سد زاینده رود به ۱۱۳ مترمکعب بر ث...             True
# 30  [ دستگیری ۷۷۸ مجرم اقتصادی در کشور\nبه گزارش م...             True
# 31  [ دستگیری ۷۷۸ مجرم اقتصادی در کشور\nبه گزارش م...             True
# 32  [ دستگیری ۷۷۸ مجرم اقتصادی در کشور\nبه گزارش م...             True
# 33  [ه مقدماتی لیگ برتر بسکتبال در سالن آزادی برگز...             True
# 34  [ابل دابل کرد تا از بازیکنان موفق شیمیدر در چه...            False
# 35  [ابل دابل کرد تا از بازیکنان موفق شیمیدر در چه...            False
# 36  [کشف 3 تابوت مومیایی تقلبی 3 هزار ساله در مراغ...             True
# 37  [کشف 3 تابوت مومیایی تقلبی 3 هزار ساله در مراغ...             True
# 38  [کشف 3 تابوت مومیایی تقلبی 3 هزار ساله در مراغ...             True
# 39  [بنای ایران| انرژی ارزان و دیوار تعرفه‌ها بلای...             True
# 40  [من دست استمداد به سمت همه نیروهای مولد و ضدفس...            False
# 41  [بنای ایران| انرژی ارزان و دیوار تعرفه‌ها بلای...             True
# 42  [اظهارات مشکوک مدیر باشگاه زنیت درباره مهاجم ت...             True
# 43  [آخرین تمرین امباپه در کنار مسی؟\nبه گزارش خبر...            False
# 44  [ کدام تیم بیشترین شانس را برای شکار امباپه دا...            False

# %%
eval_df.to_json('test_results.json', indent=2)

# %%
eval_scores
# Out:
# {'lexical': 15, 'semantic': 10, 'hybrid': 13}

# %% [markdown]
# <div dir='rtl'>
# <h2> خلاصه ی نتایج</h2>
#
# - lexical: در ۱۵ مورد از ۱۵ سوال، reference واقعی retrieve شده (امتیاز ۱۵).
#
#
# - semantic: در ۱۰ مورد موفق (امتیاز ۱۰).
#
#
# - hybrid: در ۱۳ مورد موفق (امتیاز ۱۳).
#
# <h3>تحلیل</h3>
#
# - روش lexical در retrieval دقیق‌تر عمل کرده، احتمالاً به دلیل تمرکز بر کلمات کلیدی فارسی.
#
#
# - روش semantic ممکن است به دلیل پیچیدگی‌های زبانی فارسی (مانند هم‌معنی‌ها) ضعیف‌تر باشد.
#
#
# - hybrid تعادلی بین دو روش ایجاد کرده و عملکرد بهتری نسبت به semantic خالص دارد.
#
#
# - در برخی سوالات (مانند q13 و q14)، همه روش‌ها موفق بوده‌اند، اما در مواردی مانند q15 (باشگاه فرانسوی برای سردار آزمون)، semantic و hybrid شکست خورده‌اند.
#
#
# <h3>نقاط قوت:</h3>
#
# پشتیبانی از زبان فارسی، ترکیب روش‌های retrieval، استفاده از مدل‌های پیشرفته مانند SentenceTransformer و Llama.
#
# <h3>نقاط ضعف:</h3>
#
# وابستگی به حجم chunk ها، ممکن است در سوالات پیچیده‌تر شکست بخورد، و ارزیابی محدود به ۱۵ سوال. همچنین خبر ها به روز نیستند.
#
#
# </div>
